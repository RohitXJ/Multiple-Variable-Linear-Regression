# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# # Data Processing

# %%
df = pd.read_csv('hiring.csv')
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         NaN                    8.0                           9      50000
# 1         NaN                    8.0                           6      45000
# 2         5.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6        10.0                    NaN                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
df.experience = df.experience.fillna(0)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         0.0                    8.0                           9      50000
# 1         0.0                    8.0                           6      45000
# 2         5.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6        10.0                    NaN                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
import math
test_score = math.floor(df['test_score(out of 10)'].mean()) 
test_score
# Out:
# 7

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(test_score)
df
df.columns
# Out:
# Index(['experience', 'test_score(out of 10)', 'interview_score(out of 10)',
#        'salary($)'],
#       dtype='object')

# %% [markdown]
# # Model Making

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']],df['salary($)'])
# Out:
# LinearRegression()

# %%
print(f"coef {reg.coef_} intercept {reg.intercept_}")
# Out:
# coef [2922.26901502 2221.30909959 2147.48256637] intercept 14992.65144669314

# %% [markdown]
# # Testing

# %%
# %matplotlib
df.plot()
plt.show()
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
math.floor(reg.predict([[2,9,6]]))
# Out:
# D:\Miniconda3\envs\pytorch_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\RJ\AppData\Local\Temp\ipykernel_7840\2007997330.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   math.floor(reg.predict([[2,9,6]]))
# 53713

# %%
math.floor(reg.predict([[12,10,10]]))
# Out:
# D:\Miniconda3\envs\pytorch_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\RJ\AppData\Local\Temp\ipykernel_7840\2567951278.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   math.floor(reg.predict([[12,10,10]]))
# 93747
